# %%
import pandas as pd
import numpy  as np
from bokeh.io import push_notebook, show, output_notebook
from bokeh.layouts import row
from bokeh.plotting import figure
from bokeh.models import (
    GMapPlot, GMapOptions, ColumnDataSource, Circle, DataRange1d, PanTool, WheelZoomTool, BoxSelectTool
)
output_notebook()

# %%
map_options = GMapOptions(lat=39.151042, lng=-77.193023, map_type="roadmap", zoom=11)

plot = GMapPlot(x_range=DataRange1d(), y_range=DataRange1d(), map_options=map_options)
plot.title.text = "Montgomery County"

# For GMaps to function, Google requires you obtain and enable an API key:
#
#     https://developers.google.com/maps/documentation/javascript/get-api-key
#
# Replace the value below with your personal API key:
plot.api_key = "AIzaSyAD6ZIhco9366EMts8gliNrImJiElGNJcQ"

# %%
#Loading dataset from Montgomery County complaint dataset
montydata = pd.read_csv("MontgomeryCountyCrime2013.csv")
latitudeData = montydata["Latitude"]
longitudeData = montydata["Longitude"]
montydata.head()

# %%
#Creating a master class to categorize crimes
classaux = montydata["Class"]/100
classaux = classaux.astype(int)
classaux = classaux*100
#Inserting this new data in the dataset
montydata["MasterClass"] = classaux

#print(montydata.groupby("Class")["Class Description"].mean())
#Sort by Class of complaint to analise master classes of Class complaints
montydata.sort(columns="Class")
#print(montydata.groupby["Class Description"])

# %%
source = ColumnDataSource(
    data=dict(
        lat=latitudeData[13:23],
        lon=longitudeData[13:23],
    )
)

print(source.data.values)
circle = Circle(x="lon", y="lat", size=15, fill_color="blue", fill_alpha=0.8, line_color=None)
plot.add_glyph(source, circle)

plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())

# %%
import pandas as pd
import numpy  as np
import plotly.plotly as py
import plotly.graph_objs as go
import operator

crimes = pd.read_csv("MontgomeryCountyCrime2013.csv")

#Getting Timestamp of dispatch
dates = pd.to_datetime(crimes["Dispatch Date / Time"])

#getting hours
hours = dates.dt.hour

#Getting days on week, month and wear
dates_of_month = dates.dt.day
days_of_week = dates.dt.dayofweek
days_of_year = dates.dt.dayofyear

#Getting month
months = dates.dt.month

#Getting year
years = dates.dt.year

tipos = crimes['Class Description'].str.split('-')
tipos

def principal_crime_types(data):
    dic = {}
    for crime_desc in data:
        for sub_type in crime_desc:
            sub = sub_type.lstrip().rstrip()
            if sub not in dic:
                dic[sub] = 1
            else:
                dic[sub] += 1
    return sorted(dic.items(), key=lambda x:x[1], reverse=True)

todos = principal_crime_types(tipos)
#todos

def compress_types(data):
    dic_int = {}
    dic_ext = {}
    for tip in data:
        words = tip[0].split(' ')[0:2]
        print(words)
    return words
tod = compress_types(todos)
# Out:
# ['CDS']
# ['DRIVING', 'UNDER']
# ['$199']
# ['POSS', 'MARIJUANA/HASHISH']
# ['FORGERY/CNTRFT']
# ['VANDALISM']
# ['POL', 'INFORMATION']
# ['BURG', 'FORCE']
# ['LARCENY', 'FROM']
# ['LARCENY', 'FROM']
# ['MENTAL', 'TRANSPORT']
# ['MOTOR', 'VEHICLE']
# ['LOST', 'PROPERTY']
# ['CITIZEN']
# ['LARCENY', 'OTHER']
# ['LIQUOR']
# ['LARCENY', 'FROM']
# ['IDENTITY', 'THEFT']
# ['LARCENY', 'SHOPLIFTING']
# ['LARCENY', 'SHOPLIFTING']
# ['DRINK', 'IN']
# ['MARIJUANA/HASHISH']
# ['DISORDERLY', 'CONDUCT']
# ['ASSAULT', '&']
# ['RES/DAY']
# ['AUTO', 'THEFT']
# ['SIMPLE', 'ASSAULT']
# ['LARCENY', 'FROM']
# ['CRDT', 'CARDS']
# ['MISSING', 'PERSON']
# ['BURG', 'NO']
# ['CDS', 'IMPLMNT']
# ['RES/TIME', 'UNK']
# ['PASSENGER', 'VEHICLE']
# ['ASSAULT', '&']
# ['RES/NIGHT']
# ['ATTEMPT']
# ['LARCENY', 'AUTO']
# ['JUVENILE', 'RUNAWAY']
# ['LARCENY', 'SHOPLIFTING']
# ['SELL']
# ['OTHER']
# ['SUDDEN', 'DEATH']
# ['TRESPASSING']
# ['LARCENY', 'FROM']
# ['DWELLING']
# ['LARCENY', 'OTHER']
# ['LARCENY', 'OTHER']
# ['COMM/NIGHT']
# ['ALL', 'OTHER']
# ['STREET']
# ['LARCENY', 'BICYCLE']
# ['ROB', 'STNG']
# ['LARCENY', 'FROM']
# ['RECOVERED', 'PROPERTY/MONT.']
# ['CHECKS']
# ['FAMILY', 'OFFENSE']
# ['LARCENY', 'AUTO']
# ['SUICIDE']
# ['ROB', 'FIREARM']
# ['ALL', 'OTHER']
# ['TRAFFIC', 'CRIM']
# ['SIMPLE', 'ASSAULT']
# ['SEX', 'OFFENSE']
# ['RECOVERED', 'PROPERTY/OTHER']
# ['EX', 'PARTE/PROTECT.']
# ['OPIUM', '&']
# ['ABUSE/CHILD']
# ['ASSAULT', '&']
# ['SIMPLE', 'ASSAULT']
# ['THREATENING/ANNOYING', 'PHONE']
# ['EMBEZZLE', 'CONFIDENCE']
# ['$300+']
# ['SUDDEN', 'DEATH']
# ['POSS', 'COCAINE&']
# ['OTHER', 'VEHICLES']
# ['POISON/OVERDOSE']
# ['COMMERCIAL', 'EST']
# ['UNLAWFUL', 'POSS']
# ['POSS']
# ['COMM/TIME', 'UNK']
# ['POLICE', 'OFFICER']
# ['UNAUTH.', 'USE']
# ['LARCENY', 'BICYCLE']
# ['COCAINE&', 'DERIVATIVES']
# ['HARASSMENT/STALKING']
# ['PO']
# ['FURNISHING', 'LIQUOR']
# ['WEAPON', 'CONCEALED']
# ['CDS', 'IMPLEMNT']
# ['SEX', '']
# ['FIREARM']
# ['NEGLECT/CHILD']
# ['TRUCKS', '&']
# ['RAPE']
# ['FORCE']
# ['LARCENY', 'AUTO']
# ['BAD', 'CHECKS']
# ['WEAPON', 'POSSESSION']
# ['LARCENY', 'PICK']
# ['4TH', 'DEGREE']
# ['SEX', '']
# ['UNDERAGE', 'DRINKING']
# ['AGG', 'ASSLT']
# ['EMBEZZLE', 'LARC']
# ['ROB', 'KNIFE/CUT']
# ['INDECENT', 'EXPOSURE']
# ['SCHOOL']
# ['FIRE', 'OTHER']
# ['FAIL', 'PAY']
# ['FUGITIVE', 'FROM']
# ['RECOVERED', 'PROPERTY']
# ['FALSE', 'STATEMNT/REPORT']
# ['COMM/DAY']
# ['COCAINE&', 'DERIVATI']
# ['EMBEZZLEMENT', '$300']
# ['PROSTITUTION/VICE']
# ['AGG', 'ASSLT']
# ['WEAPON', 'POSSESSION']
# ['LITTERING/TRASH', 'DUMPING']
# ['MANU']
# ['POSS', 'BARBITURATES/AMPHETAM']
# ['CUT/STAB']
# ['POSS', 'HALLUC/LSD/PCP']
# ['RES']
# ['LARCENY', 'PURSE']
# ['OPIUM&DERIVATIVE']
# ['CASH/OTHER', '$300+']
# ['CDS', 'RX']
# ['RESIDENTIAL']
# ['ROB', 'OTHER']
# ['VIOLATION', 'OF']
# ['VANDALISM', 'GRAFFITI']
# ['AGG', 'ASSLT']
# ['POSS', 'SYNTH']
# ['SEX', 'OFFENDER']
# ['REGISTRATION', 'VIOLATION']
# ['FINANCIAL', 'INSTITUTION']
# ['VANDALISM', 'GRAFFITI']
# ['COMM']
# ['VANDALISM', 'GRAFFITI']
# ['DISORDERLY', 'HOUS']
# ['WEAPON', 'CONCEALED']
# ['AGG', '']
# ['LARCENY', 'PICK']
# ['AGG', 'ASSLT']
# ['AGG', 'ASSLT']
# ['VANDALISM', 'GRAFFITI']
# ['USE', 'MARIJUANA/HASHISH']
# ['HANGING']
# ['VANDALISM', 'GRAFFITI']
# ['EMBEZZLE/THEFT']
# ['ARSON']
# ['OTHER', 'MISCELLANEOUS']
# ['COMMERCIAL']
# ['PORNOGRAPHY']
# ['BOMB', 'THREAT']
# ['PEEPING', 'TOM']
# ['SOLICIT/PANDER']
# ['AGG', '']
# ['EMBEZZLE', 'LARC']
# ['$300+', 'OTHER']
# ['MERCHANDISE/', '$300+']
# ['ALL', 'OTHER']
# ['SUSPICIOUS', 'SIT/PERSON/VEHICLE']
# ['SOLICITING/TRADE', 'W/O']
# ['CONV.', 'STORE']
# ['COM/TIME', 'UNK']
# ['ARSON', '']
# ['AGG', 'ASSLT']
# ['FAMILY', 'TROUBLE']
# ['DRUNK']
# ['AGG', 'ASSLT']
# ['JUVENILE', 'OTHER/RUNAWAY']
# ['OTHER', 'JURISDICTION']
# ['ELDER', 'ABUSE']
# ['JUVENILE', 'OFFENSE']
# ['EMBEZZLE', 'CONFIDENCE']
# ['STOLEN', 'PROP']
# ['POSSES/BUY/RECEIVE']
# ['ILL', 'PERSON']
# ['GAS/SVC', 'STA']
# ['SUDDEN', 'DEATH']
# ['LARCENY', 'PICK']
# ['WEAPON', 'POSSESSION']
# ['POSS', 'DRUG']
# ['UNOCCUPIED', 'STRUCT/OTH']
# ['USE', 'DRUG']
# ['EXPLOSIVE', 'DEVICE']
# ['BLACKMAIL/EXTORTION']
# ['SCH/NIGHT']
# ['ELDERLY']
# ['PANHANDLING']
# ['HALLUC/LSD/PCP', 'ETC']
# ['VANDAL']
# ['CONSTR/SITE/EQUIP']
# ['WEAPON', 'DISCHARGING']
# ['SYNTH', 'DEMEROL/METHADO']
# ['HOURS', 'SALE']
# ['RENTAL', 'CAR']
# ['WEAPON', 'DISCHARGING']
# ['AGG', 'ASSLT']
# ['LARCENY', 'PURSE']
# ['CHURCH/TEMPLE']
# ['ROB', 'KNIFE/CUT']
# ['OCCUPIED', 'STRUCTURE']
# ['BARBITURATES/AMPHETAM']
# ['ARSON', 'UNDER']
# ['ANIMAL', 'OFFENSE']
# ['WEAPON', 'TRAFFICIKING']
# ['AGG', 'ASSLT']
# ['INJURY']
# ['NONTRAFFIC']
# ['CDS', 'RX']
# ['LARCENY', 'PURSE']
# ['LABOR/SERVICE', '$300+']
# ['FIREWORKS']
# ['ARSON', 'ATTEMPT']
# ['HOMICIDE']
# ['DISCONDUCT']
# ['DISORDERLY', 'HOUSE(NOT']
# ['ROGUE', 'AND']
# ['ROB', 'FIREARM']
# ['FUGITIVE', 'FROM']
# ['IMPERSONATING', 'POLICE']
# ['ROB', 'STN']
# ['OVERDOSE/NOT', 'FATAL']
# ['ASPHYXIATION']
# ['USE', 'OPIUM']
# ['ELDER', 'NEGLECT']
# ['AGG', 'ANIMAL/BITE']
# ['CHILD', 'UNDER']
# ['LOITERING']
# ['USE', 'HALLUC/LSD/PCP/ETC.']
# ['CDS', 'RX']
# ['FORGERY', 'SYNTH']
# ['MANU', 'INHALANT/GLUE/AEROSOL']
# ['VEHICLE']
# ['USE', 'COCAINE&']
# ['AGG', '']
# ['LARCENY', 'BICYCLE']
# ['FAIL', 'TO']
# ['SCH/TIME', 'UNK']
# ['INDECENT', 'PHONE']
# ['LARCENY', 'COIN']
# ['ROB', 'STRONG']
# ['WELFARE', 'FRAUD']
# ['HOMELAND', 'SECURITY']
# ['SYNTH', 'DEMEROL/METH']
# ['UNOCCUP/OTHER']
# ['ROB', 'KNIFE']
# ['CASH/OTHER', 'UNDER']
# ['LABOR/SERVICE', 'UNDER']
# ['KIDNAPPING']
# ['HALLUC/LSD/PCP/ETC']
# ['HOME', 'IMPROVEMENT']
# ['MERCHANDISE/UNDER', '$300']
# ['CDS', 'IMPLMENT']
# ['HALLUC/LSD/PCP/ET']
# ['UNDER', '$300']
# ['ESCAPEE']
# ['LARCENY', 'COIN']
# ['POSS', 'INHALANT/GLUE/AEROSOL']
# ['EMBEZZLE', 'UNDER']
# ['HOT', 'CAR']
# ['PARKING', 'OFFENSES']
# ['ROB', 'OTHER']
# ['BARBITUR/AMPHETAMI']
# ['LARCENY', 'COIN']
# ['MANU', 'DRUG']
# ['ANIMAL', 'NUISANCE/BARKING']
# ['USE', 'SYNTH']
# ['SUDDEN', 'DEATH']
# ['AGG', 'ASSLT']
# ['TRAFFIC', 'HAZARD']
# ['ABANDONED', 'AUTO']
# ['VANDALISM', 'GRAFFITI']
# ['VANDALISM', 'POSSESSION']
# ['ROB', 'KNIFE/CUT']
# ['AGG', '']
# ['SCH/DAY']
# ['AGG', 'ASSLT']
# ['AGG', '']
# ['SANE', 'COLLECTION']
# ['STRANGER']
# ['AGG', 'ASSLT']
# ['CDS', 'RX']
