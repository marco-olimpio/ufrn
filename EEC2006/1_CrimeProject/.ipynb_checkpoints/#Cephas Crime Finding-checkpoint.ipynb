# %%
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
from numpy import arange
import operator

# %%
#FUNCTIONS - Calcs

def make_word_map(crime_types, words):
    dic = {}
    for word in words:
        dic[word] = {}
    for word in words:
        for ct in crime_types:
            if word in ct:
                for w in words:
                    if ((w in ct) and  (w != word)):
                        if w not in dic[word]:
                            dic[word][w] = 1
                        else:
                            dic[word][w] += 1
    #clean empty itens
    for w in words:
        if dic[w] == {}:
            del dic[w]
    return dic

#return dictionary of crime types - the type is equals to writed in original data
#dictionary key(type), value(value of it type)
def count_crimes(data):
    dic = {}
    for crime in data:
        if crime not in dic:
            dic[crime] = 1
        else:
            dic[crime] += 1
    sorted_dic = {}
    sorted_dic = sorted(dic.items(), key=operator.itemgetter(1), reverse = True)
    return sorted_dic

def take_words_from_types(data):
    new_data = []
    for j in data:
        for i in j:
            new_data.append(i.strip())
    return set(new_data)

def words_in_one_type(data):
    words = data.split('-')
    print(words)

# %%
#FUNCTIONS - CHARTS

def line_chart_time (dates):
    
    to_make = []
    #getting hours count
    hours = dates.dt.hour.value_counts().sort_index()
    #Getting days on week, month and year count
    days_of_week = dates.dt.dayofweek.value_counts().sort_index()
    dates_of_month = dates.dt.day.value_counts().sort_index()
    days_of_year = dates.dt.dayofyear.value_counts().sort_index()
    #Getting month count
    months = dates.dt.month.value_counts().sort_index()
    #Getting year count
    years = dates.dt.year.value_counts().sort_index()
    
    to_make.append(hours)
    to_make.append(days_of_week)
    to_make.append(dates_of_month)
    to_make.append(days_of_year)
    to_make.append(months)
    to_make.append(years)
    
    fig, axs = plt.subplots(6,1)
    fig.set_size_inches(14,14)
    fig.subplots_adjust(hspace=0.8)
    
    to_make[0].plot(kind='line',rot=90 ,ax=axs[0], title='Hours  - Totals')
    to_make[1].plot(kind='line',rot=90 ,ax=axs[1], title='Days of week  - Totals')
    to_make[2].plot(kind='line',rot=90 ,ax=axs[2], title='Dates of Month  - Totals')
    to_make[3].plot(kind='line',rot=90 ,ax=axs[3], title='Days of year  - Totals')
    to_make[4].plot(kind='line',rot=90 ,ax=axs[4], title='Months  - Totals')
    to_make[5].plot(kind='bar',rot=90 ,ax=axs[5], title='Years  - Totals')
    
    plt.plot()

# %%
crimes = pd.read_csv("MontgomeryCountyCrime2013.csv")

#Getting Timestamp of dispatch
dates = pd.to_datetime(crimes["Dispatch Date / Time"])

line_chart_time(dates)

# %%
#clean spaces from crime classes
crimes["Class Description"] = crimes["Class Description"].map(lambda x: x.strip())

#set all to lower case
crimes["Class Description"] = crimes["Class Description"].str.lower()

#take crime types
types = crimes["Class Description"]
#count crime types
crime_counted = count_crimes(types)

#take the words that are used to describe crimes
words_base = crimes["Class Description"].str.split('-')
words = take_words_from_types(words_base)

#Build a mapping of words(in types) inter relationed

word_map = make_word_map(types, words)
# Out:
# {'$199': {'larceny auto part $50': 40,
#   'larceny bicycle $50': 54,
#   'larceny coin mach $50': 1,
#   'larceny from auto $50': 356,
#   'larceny from building $50': 221,
#   'larceny other $50': 202,
#   'larceny pick pocket $50': 15,
#   'larceny purse snatch $50': 5,
#   'larceny shoplifting $50': 489,
#   'other': 202,
#   'po': 15},
#  '$300+': {'$300+ other': 10,
#   'bad checks': 34,
#   'cash/other $300+': 20,
#   'checks': 34,
#   'embezzle confidence games': 81,
#   'embezzle/theft': 10,
#   'labor/service $300+': 4,
#   'merchandise/ $300+': 10,
#   'other': 30},
#  '$300+ other': {'$300+': 10, 'embezzle/theft': 10, 'other': 10},
#  '4th degree sex offense': {'sex offense': 38},
#  'abuse/child': {'family offense': 88},
#  'agg  asslt beat/inj spouse/partner': {'po': 15},
#  'agg  asslt cut/stab othr domestc': {'cut/stab': 11},
#  'agg  asslt cut/stab p.o.': {'cut/stab': 1},
#  'agg  asslt firearm othr domestic': {'firearm': 2},
#  'agg animal/bite': {'animal offense': 3},
#  'agg asslt beat/inj elderly': {'elderly': 1},
#  'agg asslt cut/stab citizen': {'citizen': 36, 'cut/stab': 36},
#  'agg asslt cut/stab spouse/partner': {'cut/stab': 8, 'po': 8},
#  'agg asslt firearm citizen': {'citizen': 15, 'firearm': 15},
#  'agg asslt firearm p.o.': {'firearm': 1},
#  'agg asslt other wpn citizen': {'citizen': 26, 'other': 26},
#  'agg asslt other wpn on elderly': {'elderly': 1, 'other': 1},
#  'agg asslt other wpn othr domest': {'other': 14},
#  'agg asslt other wpn p.o.': {'other': 4},
#  'agg asslt other wpn spouse/partner': {'other': 5, 'po': 5},
#  'all other': {'all other non': 112,
#   'all other sex offense': 10,
#   'forgery/cntrft': 197,
#   'other': 319,
#   'sex offense': 10,
#   'traffic crim offenses': 112},
#  'all other non': {'all other': 112,
#   'other': 112,
#   'traffic crim offenses': 112},
#  'all other sex offense': {'all other': 10, 'other': 10, 'sex offense': 10},
#  'animal offense': {'agg animal/bite': 3, 'hot car': 1},
#  'arson': {'arson  motor vehicle': 9,
#   'arson attempt unoccupied structure/oth prop': 4,
#   'arson under invest': 4,
#   'attempt': 4,
#   'motor vehicle': 9,
#   'occupied structure': 9,
#   'other': 2,
#   'unoccup/other': 2,
#   'unoccupied struct/oth': 7,
#   'vehicle': 11},
#  'arson  motor vehicle': {'arson': 9, 'motor vehicle': 9, 'vehicle': 9},
#  'arson attempt unoccupied structure/oth prop': {'arson': 4,
#   'attempt': 4,
#   'occupied structure': 4},
#  'arson under invest': {'arson': 4,
#   'other': 2,
#   'unoccup/other': 2,
#   'vehicle': 2},
#  'asphyxiation': {'suicide': 3},
#  'assault & battery': {'assault & battery other domestic': 88,
#   'assault & battery spouse/partner': 290,
#   'citizen': 382,
#   'elderly': 4,
#   'other': 88,
#   'po': 345,
#   'police officer': 55},
#  'assault & battery other domestic': {'assault & battery': 88, 'other': 88},
#  'assault & battery spouse/partner': {'assault & battery': 290, 'po': 290},
#  'attempt': {'arson': 4,
#   'arson attempt unoccupied structure/oth prop': 4,
#   'burg force': 181,
#   'com/time unk': 9,
#   'comm': 34,
#   'comm/day': 5,
#   'comm/night': 29,
#   'cut/stab': 16,
#   'firearm': 1,
#   'force': 186,
#   'hanging': 5,
#   'occupied structure': 4,
#   'other': 11,
#   'po': 52,
#   'poison/overdose': 52,
#   'rape': 5,
#   'res': 137,
#   'res/day': 58,
#   'res/night': 45,
#   'res/time unk': 34,
#   'sch/night': 1,
#   'suicide': 85},
#  'auto theft': {'other': 71,
#   'other vehicles': 71,
#   'passenger vehicle': 293,
#   'trucks & buses': 42,
#   'vehicle': 364},
#  'bad checks': {'$300+': 34,
#   'cash/other $300+': 20,
#   'cash/other under $300': 2,
#   'checks': 40,
#   'labor/service $300+': 4,
#   'labor/service under $300': 2,
#   'merchandise/ $300+': 10,
#   'merchandise/under $300': 2,
#   'other': 22},
#  'barbitur/amphetami': {'cds': 1, 'cds implmnt': 1},
#  'barbiturates/amphetam': {'cds': 26,
#   'po': 21,
#   'poss': 21,
#   'poss barbiturates/amphetam': 21,
#   'sell': 5},
#  'burg force': {'attempt': 181,
#   'com/time unk': 9,
#   'comm': 252,
#   'comm/day': 21,
#   'comm/night': 178,
#   'comm/time unk': 53,
#   'force': 971,
#   'res': 705,
#   'res/day': 298,
#   'res/night': 189,
#   'res/time unk': 218,
#   'sch/day': 1,
#   'sch/night': 3,
#   'sch/time unk': 1},
#  'burg no force': {'comm': 40,
#   'comm/day': 7,
#   'comm/night': 20,
#   'comm/time unk': 13,
#   'force': 329,
#   'res': 285,
#   'res/day': 121,
#   'res/night': 82,
#   'res/time unk': 82,
#   'sch/night': 3,
#   'sch/time unk': 1},
#  'cash/other $300+': {'$300+': 20,
#   'bad checks': 20,
#   'checks': 20,
#   'other': 20},
#  'cash/other under $300': {'bad checks': 2, 'checks': 2, 'other': 2},
#  'cds': {'barbitur/amphetami': 1,
#   'barbiturates/amphetam': 26,
#   'cds implemnt': 48,
#   'cds implment': 2,
#   'cds implmnt': 303,
#   'cds rx': 28,
#   'cds rx forg opium & derivative': 20,
#   'cds rx forgery barbiturates/amphet': 4,
#   'cds rx forgery inhalant/glue/aeros': 1,
#   'cocaine& derivati': 158,
#   'cocaine& derivatives': 130,
#   'forgery synth demerol/metha': 3,
#   'halluc/lsd/pcp etc': 26,
#   'halluc/lsd/pcp/et': 7,
#   'halluc/lsd/pcp/etc': 5,
#   'manu': 25,
#   'manu drug overdose not fatal': 1,
#   'manu inhalant/glue/aerosol': 2,
#   'marijuana/hashish': 1819,
#   'opium & derivatives': 95,
#   'opium&derivative': 20,
#   'overdose/not fatal': 3,
#   'po': 1543,
#   'poss': 1543,
#   'poss barbiturates/amphetam': 21,
#   'poss cocaine& derivatives': 75,
#   'poss drug overdose not fatal': 7,
#   'poss halluc/lsd/pcp etc': 20,
#   'poss inhalant/glue/aerosol': 1,
#   'poss marijuana/hashish': 1334,
#   'poss synth demerol/methado': 18,
#   'sell': 253,
#   'synth demerol/meth': 29,
#   'synth demerol/methado': 24,
#   'use cocaine& derivatives': 2,
#   'use drug overdose not fatal': 7,
#   'use halluc/lsd/pcp/etc.': 3,
#   'use marijuana/hashish': 13,
#   'use opium & derivative': 3,
#   'use synth demerol/metadone': 1},
#  'cds implemnt': {'cds': 48, 'cocaine& derivati': 28, 'opium&derivative': 20},
#  'cds implment': {'cds': 2, 'halluc/lsd/pcp/et': 2},
#  'cds implmnt': {'barbitur/amphetami': 1,
#   'cds': 303,
#   'marijuana/hashish': 297,
#   'overdose/not fatal': 3,
#   'synth demerol/meth': 2},
#  'cds rx': {'cds': 28,
#   'cds rx forg opium & derivative': 20,
#   'cds rx forgery barbiturates/amphet': 4,
#   'cds rx forgery inhalant/glue/aeros': 1,
#   'forgery synth demerol/metha': 3,
#   'synth demerol/meth': 3},
#  'cds rx forg opium & derivative': {'cds': 20, 'cds rx': 20},
#  'cds rx forgery barbiturates/amphet': {'cds': 4, 'cds rx': 4},
#  'cds rx forgery inhalant/glue/aeros': {'cds': 1, 'cds rx': 1},
#  'checks': {'$300+': 34,
#   'bad checks': 40,
#   'cash/other $300+': 20,
#   'cash/other under $300': 2,
#   'forgery/cntrft': 146,
#   'labor/service $300+': 4,
#   'labor/service under $300': 2,
#   'merchandise/ $300+': 10,
#   'merchandise/under $300': 2,
#   'other': 22},
#  'child under 12 taken by parent': {'family offense': 3},
#  'church/temple': {'vandal': 5, 'vandalism': 5},
#  'citizen': {'agg asslt cut/stab citizen': 36,
#   'agg asslt firearm citizen': 15,
#   'agg asslt other wpn citizen': 26,
#   'assault & battery': 382,
#   'cut/stab': 36,
#   'firearm': 15,
#   'other': 26,
#   'simple assault': 311},
#  'cocaine& derivati': {'cds': 158,
#   'cds implemnt': 28,
#   'cocaine& derivatives': 130,
#   'po': 75,
#   'poss': 75,
#   'poss cocaine& derivatives': 75,
#   'sell': 53,
#   'use cocaine& derivatives': 2},
#  'cocaine& derivatives': {'cds': 130,
#   'cocaine& derivati': 130,
#   'po': 75,
#   'poss': 75,
#   'poss cocaine& derivatives': 75,
#   'sell': 53,
#   'use cocaine& derivatives': 2},
#  'com/time unk': {'attempt': 9, 'burg force': 9, 'force': 9},
#  'comm': {'attempt': 34,
#   'burg force': 252,
#   'burg no force': 40,
#   'comm/day': 28,
#   'comm/night': 198,
#   'comm/time unk': 66,
#   'commercial': 81,
#   'commercial est': 69,
#   'firearm': 12,
#   'force': 292,
#   'other': 2,
#   'po': 2,
#   'rob firearm': 12,
#   'rob knife/cut': 4,
#   'rob knife/cut ins': 4,
#   'rob knife/cut inst': 4,
#   'rob other weapon': 2,
#   'rob stng arm': 10,
#   'vandal': 85,
#   'vandalism': 85,
#   'vandalism graffiti commerc est': 16},
#  'comm/day': {'attempt': 5,
#   'burg force': 21,
#   'burg no force': 7,
#   'comm': 28,
#   'force': 28},
#  'comm/night': {'attempt': 29,
#   'burg force': 178,
#   'burg no force': 20,
#   'comm': 198,
#   'force': 198},
#  'comm/time unk': {'burg force': 53,
#   'burg no force': 13,
#   'comm': 66,
#   'force': 66},
#  'commercial': {'comm': 81,
#   'commercial est': 69,
#   'firearm': 12,
#   'rob firearm': 12,
#   'vandal': 69,
#   'vandalism': 69},
#  'commercial est': {'comm': 69,
#   'commercial': 69,
#   'vandal': 69,
#   'vandalism': 69},
#  'constr/site/equip': {'vandal': 6},
#  'conv. store': {'firearm': 7,
#   'rob firearm': 7,
#   'rob knife/cut': 1,
#   'rob stn arm': 2},
#  'crdt cards': {'forgery/cntrft': 342},
#  'cut/stab': {'agg  asslt cut/stab othr domestc': 11,
#   'agg  asslt cut/stab p.o.': 1,
#   'agg asslt cut/stab citizen': 36,
#   'agg asslt cut/stab spouse/partner': 8,
#   'attempt': 16,
#   'citizen': 36,
#   'po': 8,
#   'suicide': 21},
#  'disconduct': {'disorderly hous': 4, 'disorderly house(not sex)': 4},
#  'disorderly hous': {'disconduct': 4,
#   'disorderly house(not sex)': 4,
#   'prostitution/vice': 16},
#  'disorderly house(not sex)': {'disconduct': 4, 'disorderly hous': 4},
#  'drink in pub over 21': {'liquor': 482},
#  'dwelling': {'vandal': 225,
#   'vandalism': 225,
#   'vandalism graffiti dwelling': 13},
#  'elder abuse': {'family offense': 8},
#  'elder neglect': {'family offense': 3},
#  'elderly': {'agg asslt beat/inj elderly': 1,
#   'agg asslt other wpn on elderly': 1,
#   'assault & battery': 4,
#   'other': 1,
#   'simple assault': 2},
#  'embezzle confidence games': {'$300+': 81,
#   'embezzle confidence games under $300': 8},
#  'embezzle confidence games under $300': {'embezzle confidence games': 8},
#  'embezzle/theft': {'$300+': 10,
#   '$300+ other': 10,
#   'other': 12,
#   'under $300 other': 2},
#  'false statemnt/report of crime': {'po': 29},
#  'family offense': {'abuse/child': 88,
#   'child under 12 taken by parent': 3,
#   'elder abuse': 8,
#   'elder neglect': 3,
#   'neglect/child': 44},
#  'financial institution': {'firearm': 10,
#   'rob firearm': 10,
#   'rob stng arm': 7},
#  'fire other': {'other': 34},
#  'firearm': {'agg  asslt firearm othr domestic': 2,
#   'agg asslt firearm citizen': 15,
#   'agg asslt firearm p.o.': 1,
#   'attempt': 1,
#   'citizen': 15,
#   'comm': 12,
#   'commercial': 12,
#   'conv. store': 7,
#   'financial institution': 10,
#   'gas/svc sta': 7,
#   'homicide': 3,
#   'other': 23,
#   'po': 14,
#   'poss': 8,
#   'recovered property': 30,
#   'res': 12,
#   'residential': 12,
#   'rob firearm': 116,
#   'rob firearm carjack': 3,
#   'street': 56,
#   'suicide': 11,
#   'weapon discharging other firearm': 6,
#   'weapon possession other firearm': 8},
#  'force': {'attempt': 186,
#   'burg force': 971,
#   'burg no force': 329,
#   'com/time unk': 9,
#   'comm': 292,
#   'comm/day': 28,
#   'comm/night': 198,
#   'comm/time unk': 66,
#   'rape': 41,
#   'res': 990,
#   'res/day': 419,
#   'res/night': 271,
#   'res/time unk': 300,
#   'sch/day': 1,
#   'sch/night': 6,
#   'sch/time unk': 2},
#  'forgery synth demerol/metha': {'cds': 3,
#   'cds rx': 3,
#   'synth demerol/meth': 3},
#  'forgery/cntrft': {'all other': 197,
#   'checks': 146,
#   'crdt cards': 342,
#   'identity theft': 596,
#   'other': 197},
#  'fugitive from other md jurisdiction': {'other': 3},
#  'furnishing liquor under 21': {'liquor': 50},
#  'gas/svc sta': {'firearm': 7, 'rob firearm': 7, 'rob stn arm': 1},
#  'halluc/lsd/pcp etc': {'cds': 26,
#   'po': 20,
#   'poss': 20,
#   'poss halluc/lsd/pcp etc': 20,
#   'sell': 6},
#  'halluc/lsd/pcp/et': {'cds': 7,
#   'cds implment': 2,
#   'halluc/lsd/pcp/etc': 5,
#   'manu': 2,
#   'use halluc/lsd/pcp/etc.': 3},
#  'halluc/lsd/pcp/etc': {'cds': 5,
#   'halluc/lsd/pcp/et': 5,
#   'manu': 2,
#   'use halluc/lsd/pcp/etc.': 3},
#  'hanging': {'attempt': 5, 'suicide': 13},
#  'homicide': {'firearm': 3, 'other': 1},
#  'hot car': {'animal offense': 1},
#  'hours sale liquor violation': {'liquor': 6},
#  'identity theft': {'forgery/cntrft': 596},
#  'impersonating police officer': {'po': 3, 'police officer': 3},
#  'indecent exposure': {'po': 34, 'sex  offense': 34},
#  'indecent phone call': {'sex  offense': 2},
#  'injury': {'nontraffic': 4},
#  'juvenile offense other': {'other': 8},
#  'juvenile other/runaway': {'other': 8, 'other jurisdiction': 8},
#  'labor/service $300+': {'$300+': 4, 'bad checks': 4, 'checks': 4},
#  'labor/service under $300': {'bad checks': 2, 'checks': 2},
#  'larceny auto part $50': {'$199': 40},
#  'larceny bicycle $50': {'$199': 54},
#  'larceny coin mach $50': {'$199': 1},
#  'larceny from auto $50': {'$199': 356},
#  'larceny from building $50': {'$199': 221},
#  'larceny other $50': {'$199': 202, 'other': 202},
#  'larceny other over $200': {'other': 652},
#  'larceny other under $50': {'other': 209},
#  'larceny pick pocket $50': {'$199': 15, 'po': 15},
#  'larceny pick pocket over $200': {'po': 38},
#  'larceny pick pocket under $50': {'po': 8},
#  'larceny purse snatch $50': {'$199': 5},
#  'larceny shoplifting $50': {'$199': 489},
#  'liquor': {'drink in pub over 21': 482,
#   'furnishing liquor under 21': 50,
#   'hours sale liquor violation': 6,
#   'po': 67,
#   'poss': 67,
#   'underage drinking party': 36,
#   'unlawful poss under 21': 67},
#  'manu': {'cds': 25,
#   'halluc/lsd/pcp/et': 2,
#   'halluc/lsd/pcp/etc': 2,
#   'manu drug overdose not fatal': 1,
#   'manu inhalant/glue/aerosol': 2,
#   'marijuana/hashish': 18,
#   'synth demerol/meth': 2,
#   'synth demerol/methado': 2},
#  'manu drug overdose not fatal': {'cds': 1, 'manu': 1},
#  'manu inhalant/glue/aerosol': {'cds': 2, 'manu': 2},
#  'marijuana/hashish': {'cds': 1819,
#   'cds implmnt': 297,
#   'manu': 18,
#   'po': 1334,
#   'poss': 1334,
#   'poss marijuana/hashish': 1334,
#   'sell': 157,
#   'use marijuana/hashish': 13},
#  'mental transport': {'po': 841},
#  'merchandise/ $300+': {'$300+': 10, 'bad checks': 10, 'checks': 10},
#  'merchandise/under $300': {'bad checks': 2, 'checks': 2},
#  'motor vehicle': {'arson': 9,
#   'arson  motor vehicle': 9,
#   'unauth. use of motor vehicle': 54,
#   'vandal': 762,
#   'vandalism': 762,
#   'vehicle': 825},
#  'neglect/child': {'family offense': 44},
#  'nontraffic': {'injury': 4},
#  'occupied structure': {'arson': 9,
#   'arson attempt unoccupied structure/oth prop': 4,
#   'attempt': 4},
#  'opium & derivatives': {'cds': 95, 'po': 67, 'poss': 67, 'sell': 28},
#  'opium&derivative': {'cds': 20, 'cds implemnt': 20},
#  'other': {'$199': 202,
#   '$300+': 30,
#   '$300+ other': 10,
#   'agg asslt other wpn citizen': 26,
#   'agg asslt other wpn on elderly': 1,
#   'agg asslt other wpn othr domest': 14,
#   'agg asslt other wpn p.o.': 4,
#   'agg asslt other wpn spouse/partner': 5,
#   'all other': 319,
#   'all other non': 112,
#   'all other sex offense': 10,
#   'arson': 2,
#   'arson under invest': 2,
#   'assault & battery': 88,
#   'assault & battery other domestic': 88,
#   'attempt': 11,
#   'auto theft': 71,
#   'bad checks': 22,
#   'cash/other $300+': 20,
#   'cash/other under $300': 2,
#   'checks': 22,
#   'citizen': 26,
#   'comm': 2,
#   'elderly': 1,
#   'embezzle/theft': 12,
#   'fire other': 34,
#   'firearm': 23,
#   'forgery/cntrft': 197,
#   'fugitive from other md jurisdiction': 3,
#   'homicide': 1,
#   'juvenile offense other': 8,
#   'juvenile other/runaway': 8,
#   'larceny other $50': 202,
#   'larceny other over $200': 652,
#   'larceny other under $50': 209,
#   'other jurisdiction': 8,
#   'other miscellaneous': 12,
#   'other vehicles': 71,
#   'po': 127,
#   'poss': 47,
#   'recovered property': 104,
#   'recovered property/other': 104,
#   'res': 3,
#   'rob firearm': 9,
#   'rob knife/cut': 5,
#   'rob knife/cut ins': 5,
#   'rob other weapon': 20,
#   'rob other weapon gas/svc  sta': 1,
#   'rob stng arm': 29,
#   'sex offense': 10,
#   'simple assault': 87,
#   'simple assault other domestic': 87,
#   'street': 9,
#   'suicide': 17,
#   'traffic crim offenses': 112,
#   'under $300 other': 2,
#   'unoccup/other': 2,
#   'vandal': 190,
#   'vandalism': 190,
#   'vandalism graffiti other': 18,
#   'vehicle': 71,
#   'weapon concealed other weapon': 49,
#   'weapon discharging other firearm': 6,
#   'weapon possession other firearm': 8,
#   'weapon possession other weapon': 39},
#  'other jurisdiction': {'juvenile other/runaway': 8, 'other': 8},
#  'other miscellaneous': {'other': 12},
#  'other vehicles': {'auto theft': 71, 'other': 71, 'vehicle': 71},
#  'overdose/not fatal': {'cds': 3, 'cds implmnt': 3},
#  'passenger vehicle': {'auto theft': 293, 'vehicle': 293},
#  'peeping tom': {'sex offense': 11},
#  'po': {'$199': 15,
#   'agg  asslt beat/inj spouse/partner': 15,
#   'agg asslt cut/stab spouse/partner': 8,
#   'agg asslt other wpn spouse/partner': 5,
#   'assault & battery': 345,
#   'assault & battery spouse/partner': 290,
#   'attempt': 52,
#   'barbiturates/amphetam': 21,
#   'cds': 1543,
#   'cocaine& derivati': 75,
#   'cocaine& derivatives': 75,
#   'comm': 2,
#   'cut/stab': 8,
#   'false statemnt/report of crime': 29,
#   'firearm': 14,
#   'halluc/lsd/pcp etc': 20,
#   'impersonating police officer': 3,
#   'indecent exposure': 34,
#   'larceny pick pocket $50': 15,
#   'larceny pick pocket over $200': 38,
#   'larceny pick pocket under $50': 8,
#   'liquor': 67,
#   'marijuana/hashish': 1334,
#   'mental transport': 841,
#   'opium & derivatives': 67,
#   'other': 127,
#   'poison/overdose': 69,
#   'pol information': 1191,
#   'police officer': 58,
#   'pornography': 12,
#   'poss': 1690,
#   'poss barbiturates/amphetam': 21,
#   'poss cocaine& derivatives': 75,
#   'poss drug overdose not fatal': 7,
#   'poss halluc/lsd/pcp etc': 20,
#   'poss inhalant/glue/aerosol': 1,
#   'poss marijuana/hashish': 1334,
#   'poss synth demerol/methado': 18,
#   'posses/buy/receive': 8,
#   'res': 3,
#   'rob other weapon': 20,
#   'rob other weapon gas/svc  sta': 1,
#   'sex  offense': 34,
#   'simple assault': 161,
#   'simple assault spouse/partner': 111,
#   'stolen prop': 8,
#   'street': 9,
#   'suicide': 69,
#   'synth demerol/meth': 18,
#   'synth demerol/methado': 18,
#   'unlawful poss under 21': 67,
#   'vandal': 1,
#   'vandalism': 1,
#   'vandalism possession graffiti material': 1,
#   'weapon concealed handgun': 15,
#   'weapon concealed other weapon': 49,
#   'weapon discharging handgun': 5,
#   'weapon discharging other firearm': 6,
#   'weapon possession handgun': 24,
#   'weapon possession other firearm': 8,
#   'weapon possession other weapon': 39,
#   'weapon trafficiking  handgun': 4},
#  'poison/overdose': {'attempt': 52, 'po': 69, 'suicide': 69},
#  'pol information': {'po': 1191},
#  'police officer': {'assault & battery': 55,
#   'impersonating police officer': 3,
#   'po': 58},
#  'pornography': {'po': 12},
#  'poss': {'barbiturates/amphetam': 21,
#   'cds': 1543,
#   'cocaine& derivati': 75,
#   'cocaine& derivatives': 75,
#   'firearm': 8,
#   'halluc/lsd/pcp etc': 20,
#   'liquor': 67,
#   'marijuana/hashish': 1334,
#   'opium & derivatives': 67,
#   'other': 47,
#   'po': 1690,
#   'poss barbiturates/amphetam': 21,
#   'poss cocaine& derivatives': 75,
#   'poss drug overdose not fatal': 7,
#   'poss halluc/lsd/pcp etc': 20,
#   'poss inhalant/glue/aerosol': 1,
#   'poss marijuana/hashish': 1334,
#   'poss synth demerol/methado': 18,
#   'posses/buy/receive': 8,
#   'stolen prop': 8,
#   'synth demerol/meth': 18,
#   'synth demerol/methado': 18,
#   'unlawful poss under 21': 67,
#   'vandal': 1,
#   'vandalism': 1,
#   'vandalism possession graffiti material': 1,
#   'weapon possession handgun': 24,
#   'weapon possession other firearm': 8,
#   'weapon possession other weapon': 39},
#  'poss barbiturates/amphetam': {'barbiturates/amphetam': 21,
#   'cds': 21,
#   'po': 21,
#   'poss': 21},
#  'poss cocaine& derivatives': {'cds': 75,
#   'cocaine& derivati': 75,
#   'cocaine& derivatives': 75,
#   'po': 75,
#   'poss': 75},
#  'poss drug overdose not fatal': {'cds': 7, 'po': 7, 'poss': 7},
#  'poss halluc/lsd/pcp etc': {'cds': 20,
#   'halluc/lsd/pcp etc': 20,
#   'po': 20,
#   'poss': 20},
#  'poss inhalant/glue/aerosol': {'cds': 1, 'po': 1, 'poss': 1},
#  'poss marijuana/hashish': {'cds': 1334,
#   'marijuana/hashish': 1334,
#   'po': 1334,
#   'poss': 1334},
#  'poss synth demerol/methado': {'cds': 18,
#   'po': 18,
#   'poss': 18,
#   'synth demerol/meth': 18,
#   'synth demerol/methado': 18},
#  'posses/buy/receive': {'po': 8, 'poss': 8, 'stolen prop': 8},
#  'prostitution/vice': {'disorderly hous': 16, 'solicit/pander': 11},
#  'rape': {'attempt': 5, 'force': 41},
#  'recovered property': {'firearm': 30,
#   'other': 104,
#   'recovered property/mont. co.': 147,
#   'recovered property/other': 104},
#  'recovered property/mont. co.': {'recovered property': 147},
#  'recovered property/other': {'other': 104, 'recovered property': 104},
#  'registration violation': {'sex offender': 18},
#  'res': {'attempt': 137,
#   'burg force': 705,
#   'burg no force': 285,
#   'firearm': 12,
#   'force': 990,
#   'other': 3,
#   'po': 3,
#   'res/day': 419,
#   'res/night': 271,
#   'res/time unk': 300,
#   'residential': 19,
#   'rob firearm': 12,
#   'rob knife/cut': 7,
#   'rob knife/cut ins': 7,
#   'rob knife/cut inst': 7,
#   'rob other weapon': 3,
#   'rob stng arm': 17,
#   'trespassing': 223,
#   'violation of alcohol restriction': 19},
#  'res/day': {'attempt': 58,
#   'burg force': 298,
#   'burg no force': 121,
#   'force': 419,
#   'res': 419},
#  'res/night': {'attempt': 45,
#   'burg force': 189,
#   'burg no force': 82,
#   'force': 271,
#   'res': 271},
#  'res/time unk': {'attempt': 34,
#   'burg force': 218,
#   'burg no force': 82,
#   'force': 300,
#   'res': 300},
#  'residential': {'firearm': 12,
#   'res': 19,
#   'rob firearm': 12,
#   'rob knife/cut': 7,
#   'rob knife/cut ins': 7,
#   'rob knife/cut inst': 7},
#  'rob firearm': {'comm': 12,
#   'commercial': 12,
#   'conv. store': 7,
#   'financial institution': 10,
#   'firearm': 116,
#   'gas/svc sta': 7,
#   'other': 9,
#   'res': 12,
#   'residential': 12,
#   'rob firearm carjack': 3,
#   'street': 56},
#  'rob firearm carjack': {'firearm': 3, 'rob firearm': 3},
#  'rob knife/cut': {'comm': 4,
#   'conv. store': 1,
#   'other': 5,
#   'res': 7,
#   'residential': 7,
#   'rob knife/cut ins': 40,
#   'rob knife/cut inst': 35,
#   'street': 24},
#  'rob knife/cut ins': {'comm': 4,
#   'other': 5,
#   'res': 7,
#   'residential': 7,
#   'rob knife/cut': 40,
#   'rob knife/cut inst': 35,
#   'street': 24},
#  'rob knife/cut inst': {'comm': 4,
#   'res': 7,
#   'residential': 7,
#   'rob knife/cut': 35,
#   'rob knife/cut ins': 35,
#   'street': 24},
#  'rob other weapon': {'comm': 2,
#   'other': 20,
#   'po': 20,
#   'res': 3,
#   'rob other weapon gas/svc  sta': 1,
#   'street': 9},
#  'rob other weapon gas/svc  sta': {'other': 1, 'po': 1, 'rob other weapon': 1},
#  'rob stn arm': {'conv. store': 2, 'gas/svc sta': 1},
#  'rob stng arm': {'comm': 10,
#   'financial institution': 7,
#   'other': 29,
#   'res': 17,
#   'street': 106},
#  'sane collection non': {'stranger': 1},
#  'sch/day': {'burg force': 1, 'force': 1},
#  'sch/night': {'attempt': 1, 'burg force': 3, 'burg no force': 3, 'force': 6},
#  'sch/time unk': {'burg force': 1, 'burg no force': 1, 'force': 2},
#  'school': {'vandal': 46, 'vandalism': 46, 'vandalism graffiti school': 12},
#  'sell': {'barbiturates/amphetam': 5,
#   'cds': 253,
#   'cocaine& derivati': 53,
#   'cocaine& derivatives': 53,
#   'halluc/lsd/pcp etc': 6,
#   'marijuana/hashish': 157,
#   'opium & derivatives': 28,
#   'synth demerol/meth': 4,
#   'synth demerol/methado': 4},
#  'sex  assault': {'sex offense': 47},
#  'sex  offense': {'indecent exposure': 34, 'indecent phone call': 2, 'po': 34},
#  'sex offender': {'registration violation': 18},
#  'sex offense': {'4th degree sex offense': 38,
#   'all other': 10,
#   'all other sex offense': 10,
#   'other': 10,
#   'peeping tom': 11,
#   'sex  assault': 47},
#  'simple assault': {'citizen': 311,
#   'elderly': 2,
#   'other': 87,
#   'po': 161,
#   'simple assault other domestic': 87,
#   'simple assault spouse/partner': 111},
#  'simple assault other domestic': {'other': 87, 'simple assault': 87},
#  'simple assault spouse/partner': {'po': 111, 'simple assault': 111},
#  'solicit/pander': {'prostitution/vice': 11},
#  'stolen prop': {'po': 8, 'poss': 8, 'posses/buy/receive': 8},
#  'stranger': {'sane collection non': 1},
#  'street': {'firearm': 56,
#   'other': 9,
#   'po': 9,
#   'rob firearm': 56,
#   'rob knife/cut': 24,
#   'rob knife/cut ins': 24,
#   'rob knife/cut inst': 24,
#   'rob other weapon': 9,
#   'rob stng arm': 106},
#  'suicide': {'asphyxiation': 3,
#   'attempt': 85,
#   'cut/stab': 21,
#   'firearm': 11,
#   'hanging': 13,
#   'other': 17,
#   'po': 69,
#   'poison/overdose': 69},
#  'suspicious sit/person/vehicle': {'vehicle': 10},
#  'synth demerol/meth': {'cds': 29,
#   'cds implmnt': 2,
#   'cds rx': 3,
#   'forgery synth demerol/metha': 3,
#   'manu': 2,
#   'po': 18,
#   'poss': 18,
#   'poss synth demerol/methado': 18,
#   'sell': 4,
#   'synth demerol/methado': 24},
#  'synth demerol/methado': {'cds': 24,
#   'manu': 2,
#   'po': 18,
#   'poss': 18,
#   'poss synth demerol/methado': 18,
#   'sell': 4,
#   'synth demerol/meth': 24},
#  'traffic crim offenses': {'all other': 112,
#   'all other non': 112,
#   'other': 112},
#  'trespassing': {'res': 223},
#  'trucks & buses': {'auto theft': 42},
#  'unauth. use of motor vehicle': {'motor vehicle': 54, 'vehicle': 54},
#  'under $300 other': {'embezzle/theft': 2, 'other': 2},
#  'underage drinking party': {'liquor': 36},
#  'unlawful poss under 21': {'liquor': 67, 'po': 67, 'poss': 67},
#  'unoccup/other': {'arson': 2, 'arson under invest': 2, 'other': 2},
#  'unoccupied struct/oth': {'arson': 7},
#  'use cocaine& derivatives': {'cds': 2,
#   'cocaine& derivati': 2,
#   'cocaine& derivatives': 2},
#  'use drug overdose not fatal': {'cds': 7},
#  'use halluc/lsd/pcp/etc.': {'cds': 3,
#   'halluc/lsd/pcp/et': 3,
#   'halluc/lsd/pcp/etc': 3},
#  'use marijuana/hashish': {'cds': 13, 'marijuana/hashish': 13},
#  'use opium & derivative': {'cds': 3},
#  'use synth demerol/metadone': {'cds': 1},
#  'vandal': {'church/temple': 5,
#   'comm': 85,
#   'commercial': 69,
#   'commercial est': 69,
#   'constr/site/equip': 6,
#   'dwelling': 225,
#   'motor vehicle': 762,
#   'other': 190,
#   'po': 1,
#   'poss': 1,
#   'school': 46,
#   'vandalism': 1332,
#   'vandalism graffiti church/temp': 1,
#   'vandalism graffiti commerc est': 16,
#   'vandalism graffiti dwelling': 13,
#   'vandalism graffiti motor veh': 17,
#   'vandalism graffiti other': 18,
#   'vandalism graffiti school': 12,
#   'vandalism possession graffiti material': 1,
#   'vehicle': 762},
#  'vandalism': {'church/temple': 5,
#   'comm': 85,
#   'commercial': 69,
#   'commercial est': 69,
#   'dwelling': 225,
#   'motor vehicle': 762,
#   'other': 190,
#   'po': 1,
#   'poss': 1,
#   'school': 46,
#   'vandal': 1332,
#   'vandalism graffiti church/temp': 1,
#   'vandalism graffiti commerc est': 16,
#   'vandalism graffiti dwelling': 13,
#   'vandalism graffiti motor veh': 17,
#   'vandalism graffiti other': 18,
#   'vandalism graffiti school': 12,
#   'vandalism possession graffiti material': 1,
#   'vehicle': 762},
#  'vandalism graffiti church/temp': {'vandal': 1, 'vandalism': 1},
#  'vandalism graffiti commerc est': {'comm': 16, 'vandal': 16, 'vandalism': 16},
#  'vandalism graffiti dwelling': {'dwelling': 13,
#   'vandal': 13,
#   'vandalism': 13},
#  'vandalism graffiti motor veh': {'vandal': 17, 'vandalism': 17},
#  'vandalism graffiti other': {'other': 18, 'vandal': 18, 'vandalism': 18},
#  'vandalism graffiti school': {'school': 12, 'vandal': 12, 'vandalism': 12},
#  'vandalism possession graffiti material': {'po': 1,
#   'poss': 1,
#   'vandal': 1,
#   'vandalism': 1},
#  'vehicle': {'arson': 11,
#   'arson  motor vehicle': 9,
#   'arson under invest': 2,
#   'auto theft': 364,
#   'motor vehicle': 825,
#   'other': 71,
#   'other vehicles': 71,
#   'passenger vehicle': 293,
#   'suspicious sit/person/vehicle': 10,
#   'unauth. use of motor vehicle': 54,
#   'vandal': 762,
#   'vandalism': 762},
#  'violation of alcohol restriction': {'res': 19},
#  'weapon concealed handgun': {'po': 15},
#  'weapon concealed other weapon': {'other': 49, 'po': 49},
#  'weapon discharging handgun': {'po': 5},
#  'weapon discharging other firearm': {'firearm': 6, 'other': 6, 'po': 6},
#  'weapon possession handgun': {'po': 24, 'poss': 24},
#  'weapon possession other firearm': {'firearm': 8,
#   'other': 8,
#   'po': 8,
#   'poss': 8},
#  'weapon possession other weapon': {'other': 39, 'po': 39, 'poss': 39},
#  'weapon trafficiking  handgun': {'po': 4}}
